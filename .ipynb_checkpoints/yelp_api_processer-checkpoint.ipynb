# %%
# Imports
import pandas as pd
import requests
from api_keys import yelp_api_key

# %%
# Configure API URI
uri = 'https://api.yelp.com/v3/businesses/search'

payload = {
    'term': 'restaurants',
    'location': 'san francisco',
    'limit': 50,
    'offset': 0
}

headers = {
    'Authorization': f"Bearer {yelp_api_key}"
    
}

# %%
api_key
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2bf5c3df5d0e> in <module>
# ----> 1 api_key
#
# NameError: name 'api_key' is not defined

# %%
# Perform API Request for restaurants in SF
# https://api.yelp.com/v3/businesses/search?term=restaurants&location=san francisco

# %%
response = requests.get(uri, params=payload, headers=headers)

# %%
response.json()
# Out:
# {'businesses': [{'id': 'f-m7-hyFzkf0HSEeQ2s-9A',
#    'alias': 'fog-harbor-fish-house-san-francisco-2',
#    'name': 'Fog Harbor Fish House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lv7tIRX3Bim9bKqtWifmNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fog-harbor-fish-house-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 6058,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.809041, 'longitude': -122.410233},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': 'Pier 39',
#     'address2': 'Ste A-202',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['Pier 39', 'Ste A-202', 'San Francisco, CA 94133']},
#    'phone': '+14154212442',
#    'display_phone': '(415) 421-2442',
#    'distance': 5827.740044156521},
#   {'id': 'XQLmEdXoMzOpffwoFaBtaQ',
#    'alias': 'kitchen-story-san-francisco',
#    'name': 'Kitchen Story',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Qjl6sGrNGbBlY-r-1jaYzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-story-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3341,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7642352, 'longitude': -122.4306936},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '3499 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3499 16th St', 'San Francisco, CA 94114']},
#    'phone': '+14155254905',
#    'display_phone': '(415) 525-4905',
#    'distance': 625.1566435901884},
#   {'id': 'vLNzJX1ctfP4NNESCFOeGw',
#    'alias': 'son-and-garden-san-francisco',
#    'name': 'Son & Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GwNYDeFAhiYhS1zlyXIFAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/son-and-garden-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 56,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.783387, 'longitude': -122.419016},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '700 Polk St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['700 Polk St', 'San Francisco, CA 94109']},
#    'phone': '+14159137404',
#    'display_phone': '(415) 913-7404',
#    'distance': 2927.3452260692093},
#   {'id': '8kck3-K4zYKTJbJko0JlXQ',
#    'alias': 'farmhouse-kitchen-thai-cuisine-san-francisco',
#    'name': 'Farmhouse Kitchen Thai Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/woO06sua7uMQNBf0wnjf8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmhouse-kitchen-thai-cuisine-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2427,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76026094, 'longitude': -122.4112048},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '710 Florida St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['710 Florida St', 'San Francisco, CA 94110']},
#    'phone': '+14158142920',
#    'display_phone': '(415) 814-2920',
#    'distance': 2220.139249062676},
#   {'id': 'wxzx3duu1c0CcomzEOvfOQ',
#    'alias': 'the-front-porch-san-francisco',
#    'name': 'The Front Porch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0fmMVyqSKOMIqtkQksUTUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-front-porch-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2821,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7438, 'longitude': -122.422035},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '65 29th St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['65 29th St', 'Ste A', 'San Francisco, CA 94110']},
#    'phone': '+14156957800',
#    'display_phone': '(415) 695-7800',
#    'distance': 2285.237602234066},
#   {'id': 'lJAGnYzku5zSaLnQ_T6_GQ',
#    'alias': 'brendas-french-soul-food-san-francisco-5',
#    'name': "Brenda's French Soul Food",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sNIJnePGDenUOyewsD8tLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brendas-french-soul-food-san-francisco-5?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 11001,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7829016035273,
#     'longitude': -122.419043442957},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '652 Polk St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['652 Polk St', 'San Francisco, CA 94102']},
#    'phone': '+14153458100',
#    'display_phone': '(415) 345-8100',
#    'distance': 2885.38913097158},
#   {'id': 'i09UMzccKgyLwGYKDVP28w',
#    'alias': 'surisan-san-francisco',
#    'name': 'Surisan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ortP_EOCgYeUwjn9dEn84g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/surisan-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1913,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.80678, 'longitude': -122.41756},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '505 Beach St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['505 Beach St', 'San Francisco, CA 94133']},
#    'phone': '+14157718449',
#    'display_phone': '(415) 771-8449',
#    'distance': 5366.476620396218},
#   {'id': 'DGyoVB9PdI9_jw0CNi_OPg',
#    'alias': 'suppenküche-san-francisco-2',
#    'name': 'Suppenküche',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HAumhGEjTcqstgie00Fjag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suppenk%C3%BCche-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3128,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7762603759766,
#     'longitude': -122.426391601562},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '525 Laguna St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['525 Laguna St', 'San Francisco, CA 94102']},
#    'phone': '+14152529289',
#    'display_phone': '(415) 252-9289',
#    'distance': 1919.7883063813613},
#   {'id': 'Xg-FyjVKAN70LO4u4Z1ozg',
#    'alias': 'hog-island-oyster-co-san-francisco',
#    'name': 'Hog Island Oyster Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TW9FgV_Ufqd15t_ARQuz1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hog-island-oyster-co-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 5981,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.795831, 'longitude': -122.393303},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Ferry Bldg',
#     'address2': '',
#     'address3': 'Shop 11',
#     'city': 'San Francisco',
#     'zip_code': '94111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1 Ferry Bldg', 'Shop 11', 'San Francisco, CA 94111']},
#    'phone': '+14153917117',
#    'display_phone': '(415) 391-7117',
#    'distance': 5428.15670676801},
#   {'id': 'eYXwVR4mMAjzkJnm5wneHQ',
#    'alias': 'burma-superstar-san-francisco-2',
#    'name': 'Burma Superstar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rt-zOS-uNY0cafsq1UeoDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burma-superstar-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 6765,
#    'categories': [{'alias': 'burmese', 'title': 'Burmese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.782787322998,
#     'longitude': -122.462539672852},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '309 Clement St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['309 Clement St', 'San Francisco, CA 94118']},
#    'phone': '+14153872147',
#    'display_phone': '(415) 387-2147',
#    'distance': 3348.056372269087},
#   {'id': 'HHtpR0RslupSQ99GIIwW5A',
#    'alias': 'marufuku-ramen-sf-san-francisco',
#    'name': 'Marufuku Ramen SF',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WiaA3cGOciKGU1099ViqeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marufuku-ramen-sf-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2961,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.785014, 'longitude': -122.431842},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1581 Webster St',
#     'address2': 'Ste 235',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1581 Webster St',
#      'Ste 235',
#      'San Francisco, CA 94115']},
#    'phone': '+14158729786',
#    'display_phone': '(415) 872-9786',
#    'distance': 2710.1678399585257},
#   {'id': 'zWSf5FEWPQKhTI9d40-uMA',
#    'alias': 'jordans-kitchen-san-francisco',
#    'name': "Jordan's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/36KKEaNSWk0uiTZvzslSKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jordans-kitchen-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 258,
#    'categories': [{'alias': 'cookingclasses', 'title': 'Cooking Classes'},
#     {'alias': 'teambuilding', 'title': 'Team Building Activities'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.7714538574219,
#     'longitude': -122.410682678223},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '413 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['413 10th St', 'San Francisco, CA 94103']},
#    'phone': '+14158729160',
#    'display_phone': '(415) 872-9160',
#    'distance': 2545.4858564855053},
#   {'id': 'BjlVE7tTp1UCEttgkM1Big',
#    'alias': 'beit-rima-san-francisco-3',
#    'name': 'Beit Rima',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7j77HFHqc-mJkfdFK2T94g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beit-rima-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 322,
#    'categories': [{'alias': 'arabian', 'title': 'Arabian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76872, 'longitude': -122.42943},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '138 Church St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['138 Church St', 'San Francisco, CA 94114']},
#    'phone': '+14157030270',
#    'display_phone': '(415) 703-0270',
#    'distance': 1073.1993439779797},
#   {'id': 'WOVHQYzSAdyXYOiYDTmujQ',
#    'alias': 'the-bird-san-francisco',
#    'name': 'The Bird',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2F4-7ng-LIJiiHMb6evqDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bird-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1774,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78724, 'longitude': -122.39995},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '115 New Montgomery St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94105',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['115 New Montgomery St', 'San Francisco, CA 94105']},
#    'phone': '+14158729825',
#    'display_phone': '(415) 872-9825',
#    'distance': 4334.402024411518},
#   {'id': 'bH8FgQYhxkj5qQ4wL7vPFA',
#    'alias': 'tuba-authentic-turkish-restaurant-san-francisco',
#    'name': 'Tuba Authentic Turkish Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xLnGt1Xzex00DtcVS1mqBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuba-authentic-turkish-restaurant-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1027,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.754898, 'longitude': -122.422906},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1007 Guerrero St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1007 Guerrero St', 'San Francisco, CA 94110']},
#    'phone': '+14158268822',
#    'display_phone': '(415) 826-8822',
#    'distance': 1361.904040975519},
#   {'id': 'dY0Mc_PHH6nLENvWmVtwxQ',
#    'alias': 'daeho-kalbijjim-and-beef-soup-san-francisco-9',
#    'name': 'Daeho Kalbijjim & Beef Soup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LaFYy38ZDs39NsqIm6Wz4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daeho-kalbijjim-and-beef-soup-san-francisco-9?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 767,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78601, 'longitude': -122.42858},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1620 Post St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1620 Post St', 'San Francisco, CA 94115']},
#    'phone': '+14155631388',
#    'display_phone': '(415) 563-1388',
#    'distance': 2867.8335670207744},
#   {'id': 'WavvLdfdP6g8aZTtbBQHTw',
#    'alias': 'gary-danko-san-francisco',
#    'name': 'Gary Danko',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CAprIoeKQAYV9oUw9xBbmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gary-danko-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 5523,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.80587, 'longitude': -122.42058},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '800 N Point St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['800 N Point St', 'San Francisco, CA 94109']},
#    'phone': '+14157492060',
#    'display_phone': '(415) 749-2060',
#    'distance': 5191.341803207417},
#   {'id': 'DL-2iaugPoULjvZ6pyNRAQ',
#    'alias': 'causwells-san-francisco-5',
#    'name': 'Causwells',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TVoM-20ZGYrdFou2SqcuiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/causwells-san-francisco-5?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 753,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.8001342713833,
#     'longitude': -122.441983893514},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2346 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2346 Chestnut St', 'San Francisco, CA 94123']},
#    'phone': '+14154476081',
#    'display_phone': '(415) 447-6081',
#    'distance': 4402.702661060376},
#   {'id': 'PsY5DMHxa5iNX_nX0T-qPA',
#    'alias': 'kokkari-estiatorio-san-francisco',
#    'name': 'Kokkari Estiatorio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7StMTfE2srlcIu2opeTb3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kokkari-estiatorio-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 4523,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.796996, 'longitude': -122.399661},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '200 Jackson St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['200 Jackson St', 'San Francisco, CA 94111']},
#    'phone': '+14159810983',
#    'display_phone': '(415) 981-0983',
#    'distance': 5153.879756630951},
#   {'id': 'pPzSZ_E9KUl625SeNRFrXQ',
#    'alias': 'bonita-taqueria-y-rotisserie-san-francisco-3',
#    'name': 'Bonita Taqueria Y Rotisserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q6uiZ9KdhdPK5OifgBERUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonita-taqueria-y-rotisserie-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 16,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76439, 'longitude': -122.4334},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '3600 16th St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3600 16th St', 'San Francisco, CA 94114']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 458.42282380585215},
#   {'id': '1hMD7RQogPDWpE-p3LKjXA',
#    'alias': 'loló-san-francisco-4',
#    'name': 'Loló',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-_hqewRYasro3NpC-v4Fug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lol%C3%B3-san-francisco-4?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2196,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7573462, 'longitude': -122.4214034},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '974 Valencia St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['974 Valencia St', 'San Francisco, CA 94110']},
#    'phone': '+14156435656',
#    'display_phone': '(415) 643-5656',
#    'distance': 1380.24804973913},
#   {'id': 'UGKNNQ6bjL-ZttHSdZISfA',
#    'alias': 'blackwood-san-francisco-3',
#    'name': 'Blackwood',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Vjw66J0_vVHmjLTUYq3Uog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackwood-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1625,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.800591, 'longitude': -122.438832},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2150 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2150 Chestnut St', 'San Francisco, CA 94123']},
#    'phone': '+14159319663',
#    'display_phone': '(415) 931-9663',
#    'distance': 4418.474572931308},
#   {'id': '-DrR38H1Abk0wCyu9XOLug',
#    'alias': 'sweet-maple-san-francisco',
#    'name': 'Sweet Maple',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rNkGdgZzwlcO4k0sVGdOCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-maple-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3671,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.785735681426, 'longitude': -122.43507770852},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2101 Sutter St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2101 Sutter St', 'San Francisco, CA 94115']},
#    'phone': '+14156559169',
#    'display_phone': '(415) 655-9169',
#    'distance': 2764.2882648857435},
#   {'id': 'O1sRAas2IZQKYVSNZeBagQ',
#    'alias': 'cracked-and-battered-san-francisco',
#    'name': 'Cracked & Battered',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yD4wbjvAS8G0yxnQ-C-JKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cracked-and-battered-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 706,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76266, 'longitude': -122.39719},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1434 18th St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1434 18th St', 'San Francisco, CA 94107']},
#    'phone': '+14159268645',
#    'display_phone': '(415) 926-8645',
#    'distance': 3444.784701280227},
#   {'id': 'yjk8RMe_sNFpkLCsKKuCvw',
#    'alias': 'tadu-ethiopian-kitchen-san-francisco-7',
#    'name': 'Tadu Ethiopian Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RgIlnmz3VAo3nznAL_0tyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tadu-ethiopian-kitchen-san-francisco-7?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 250,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.773497320774,
#     'longitude': -122.391527131952},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1120-30 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94158',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1120-30 4th St', 'San Francisco, CA 94158']},
#    'phone': '+14156559344',
#    'display_phone': '(415) 655-9344',
#    'distance': 4198.24822788222},
#   {'id': 'lgD2BDiMtW3UhM6rk3IUNw',
#    'alias': 'chicken-as-cluck-san-francisco',
#    'name': 'Chicken as Cluck',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lzHGEUlhlRCxWJD7LacVEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chicken-as-cluck-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 67,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.750541, 'longitude': -122.395028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1760 Cesar Chavez St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94124',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1760 Cesar Chavez St', 'San Francisco, CA 94124']},
#    'phone': '+14156700428',
#    'display_phone': '(415) 670-0428',
#    'distance': 3828.195824416879},
#   {'id': 'r7RwvYMwxDuK3u26fHbYDA',
#    'alias': 'limón-rotisserie-san-francisco-3',
#    'name': 'Limón Rotisserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wvbMWakjpf0c-0QeucFl9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lim%C3%B3n-rotisserie-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3197,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7570514, 'longitude': -122.416461},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1001 S Van Ness Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1001 S Van Ness Ave', 'San Francisco, CA 94110']},
#    'phone': '+14158212134',
#    'display_phone': '(415) 821-2134',
#    'distance': 1808.3298970637697},
#   {'id': 'IlkvuSkI1LF5y-Q3jpWrWQ',
#    'alias': 'cafe-de-casa-san-francisco-4',
#    'name': 'Cafe De Casa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1NxXWq9qdY1moLVYcfuIeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-de-casa-san-francisco-4?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 19,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.76236, 'longitude': -122.43471},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '3985 17th St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3985 17th St', 'San Francisco, CA 94114']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 215.2119630085956},
#   {'id': 'gqVl3RprESEqkIPeJH0yOg',
#    'alias': 'zazie-san-francisco',
#    'name': 'Zazie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uuRvEU-cqPk-XlDbFAQjKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zazie-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 4388,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.765244, 'longitude': -122.4501138},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '941 Cole St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['941 Cole St', 'San Francisco, CA 94117']},
#    'phone': '+14155645332',
#    'display_phone': '(415) 564-5332',
#    'distance': 1294.8624343961546},
#   {'id': 'wZv5s1J3xmUkO-x9b8_-yQ',
#    'alias': 'rustys-southern-san-francisco',
#    'name': "Rusty's Southern",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QyRA7KSptR_rZpJ5ommR7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rustys-southern-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1020,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7844, 'longitude': -122.41855},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '750 Ellis St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['750 Ellis St', 'San Francisco, CA 94109']},
#    'phone': '+14156386974',
#    'display_phone': '(415) 638-6974',
#    'distance': 3039.0131663781394},
#   {'id': 'ttarnopezxmp2ROB1N2PaA',
#    'alias': 'nopa-san-francisco',
#    'name': 'Nopa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/16cGmQsklyiMpSCbwz8dLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nopa-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 5067,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77483, 'longitude': -122.43746},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '560 Divisadero St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['560 Divisadero St', 'San Francisco, CA 94117']},
#    'phone': '+14158648643',
#    'display_phone': '(415) 864-8643',
#    'distance': 1559.1831881623302},
#   {'id': '-Y_9AT6NpvHz15vd4B0CbA',
#    'alias': 'tselogs-san-francisco-5',
#    'name': 'Tselogs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KSEFNNCB3fopA9V8Qn5LSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tselogs-san-francisco-5?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 634,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.786503, 'longitude': -122.412917},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '552 Jones St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['552 Jones St', 'San Francisco, CA 94102']},
#    'phone': '+14156587142',
#    'display_phone': '(415) 658-7142',
#    'distance': 3517.4069624550566},
#   {'id': 'cL0q9S4bqwpbAN9ZKh-Zeg',
#    'alias': 'nara-restaurant-and-sake-bar-san-francisco',
#    'name': 'Nara Restaurant & Sake Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7zzlpJKaC9bndjuo2UIr6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nara-restaurant-and-sake-bar-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1056,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7721665317965,
#     'longitude': -122.430675700307},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '518 Haight St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['518 Haight St', 'San Francisco, CA 94117']},
#    'phone': '+14156386124',
#    'display_phone': '(415) 638-6124',
#    'distance': 1351.6641305802066},
#   {'id': 'VPXezwmTETrwitrzj9BZPA',
#    'alias': 'dumpling-time-san-francisco',
#    'name': 'Dumpling Time',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LpVJS1JQ5thyPRCT99mMCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dumpling-time-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1839,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7697533, 'longitude': -122.4022546},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '11 Division St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['11 Division St', 'San Francisco, CA 94103']},
#    'phone': '+14155254797',
#    'display_phone': '(415) 525-4797',
#    'distance': 3151.2428912681967},
#   {'id': 'HaAb_L9zVNLjJwrBkSf_Vw',
#    'alias': 'pier-market-seafood-restaurant-san-francisco',
#    'name': 'Pier Market Seafood Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oiWv-yEYYS62vOvFC97sTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pier-market-seafood-restaurant-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2112,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.8099386456994,
#     'longitude': -122.410550415516},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': 'Pier 39',
#     'address2': 'Ste 103',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['Pier 39', 'Ste 103', 'San Francisco, CA 94133']},
#    'phone': '+14159897437',
#    'display_phone': '(415) 989-7437',
#    'distance': 5908.750879956415},
#   {'id': 'c0WpyZFR3EoEBKcoY2LZ3Q',
#    'alias': 'marlowe-san-francisco-2',
#    'name': 'Marlowe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4CskEpDaE2yCeF7VI5UYOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marlowe-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2720,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77828, 'longitude': -122.39686},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '500 Brannan St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['500 Brannan St', 'San Francisco, CA 94107']},
#    'phone': '+14157771413',
#    'display_phone': '(415) 777-1413',
#    'distance': 3977.7682689926487},
#   {'id': '2nXYpojLdnIWkFW-Xe7B2A',
#    'alias': 'padrecito-san-francisco',
#    'name': 'Padrecito',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BkdlyO05_0w0fhA-gkq78A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padrecito-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 930,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7656775, 'longitude': -122.4500746},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '901 Cole St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['901 Cole St', 'San Francisco, CA 94117']},
#    'phone': '+14157425505',
#    'display_phone': '(415) 742-5505',
#    'distance': 1310.453997730548},
#   {'id': 'Su1ay8vJyKsHZKQG_eluaA',
#    'alias': 'dragon-beaux-san-francisco',
#    'name': 'Dragon Beaux',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fmX3U2vlg_u60aRNVHNIqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dragon-beaux-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1590,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.780504, 'longitude': -122.480709},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '5700 Geary Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5700 Geary Blvd', 'San Francisco, CA 94121']},
#    'phone': '+14153338899',
#    'display_phone': '(415) 333-8899',
#    'distance': 4459.919274452497},
#   {'id': 'd5752S_RDb26HxoL6O06eQ',
#    'alias': 'beit-rima-san-francisco-4',
#    'name': 'Beit Rima',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QhmsZQi_AsniRJ_Xoq4yeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beit-rima-san-francisco-4?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 32,
#    'categories': [{'alias': 'arabian', 'title': 'Arabian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.765956, 'longitude': -122.449679},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '86 Carl St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['86 Carl St', 'San Francisco, CA 94117']},
#    'phone': '+14155661274',
#    'display_phone': '(415) 566-1274',
#    'distance': 1291.888183200842},
#   {'id': 'sfqkkqFmmYGOT0PCbbD9ZQ',
#    'alias': 'pearl-6101-san-francisco-6',
#    'name': 'Pearl 6101',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Iy2vlDWe-Xa70zbbPdgZHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pearl-6101-san-francisco-6?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 238,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7838344, 'longitude': -122.4830463},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '6101 California St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6101 California St', 'San Francisco, CA 94121']},
#    'phone': '+14155929777',
#    'display_phone': '(415) 592-9777',
#    'distance': 4827.880111203369},
#   {'id': 'E2Ri3Uudb3ogKfWBJIIhRw',
#    'alias': 'lokma-san-francisco',
#    'name': 'Lokma',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RjLrstaXwxkvfllM-GY-kQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lokma-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 272,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78215, 'longitude': -122.47867},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1801 Clement St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1801 Clement St', 'San Francisco, CA 94121']},
#    'phone': '+14157026219',
#    'display_phone': '(415) 702-6219',
#    'distance': 4402.2665821297205},
#   {'id': '_1pt3zjz2Om9QC3OUSuTtA',
#    'alias': 'mahila-san-francisco-2',
#    'name': 'Mahila',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aNFRCMETtXbLxJa-yWB--Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mahila-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 132,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.750925, 'longitude': -122.4342714},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1320 Castro St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1320 Castro St', 'San Francisco, CA 94114']},
#    'phone': '+16288673570',
#    'display_phone': '(628) 867-3570',
#    'distance': 1125.4734607019},
#   {'id': 'JIrpgjojJYGmZmRZh9HD0Q',
#    'alias': 'dokkaebier-san-francisco',
#    'name': 'Dokkaebier',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mJTod29zu_uyk1yIJv1Mzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dokkaebier-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 17,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'popuprestaurants', 'title': 'Pop-Up Restaurants'},
#     {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.792865, 'longitude': -122.421444},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1735 Polk St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1735 Polk St', 'San Francisco, CA 94109']},
#    'phone': '+14156253203',
#    'display_phone': '(415) 625-3203',
#    'distance': 3797.9710747785325},
#   {'id': 'LjVlsV9tKGnv7e4Iyt9c5Q',
#    'alias': 'lark-san-francisco-2',
#    'name': 'Lark',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BiDUDWE3pDcZnRRvDk7ruA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lark-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 289,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.761243, 'longitude': -122.434248},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '4068 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4068 18th St', 'San Francisco, CA 94114']},
#    'phone': '+14154004623',
#    'display_phone': '(415) 400-4623',
#    'distance': 197.0605128915999},
#   {'id': 'BI40rGhpngLNPacrjWpseQ',
#    'alias': 'dumpling-kitchen-san-francisco',
#    'name': 'Dumpling Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ogP7vwDntfvnaW7VsOudzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dumpling-kitchen-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1542,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7423, 'longitude': -122.48701},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1935 Taraval St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1935 Taraval St', 'San Francisco, CA 94116']},
#    'phone': '+14156828938',
#    'display_phone': '(415) 682-8938',
#    'distance': 4904.15624633216},
#   {'id': 'ykvr3ib1gHQHI4tznSn8iA',
#    'alias': 'wayfare-tavern-san-francisco-2',
#    'name': 'Wayfare Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PF0Gwry7SVfbI5tforgXgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wayfare-tavern-san-francisco-2?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 3904,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7939484886016,
#     'longitude': -122.402307987213},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '558 Sacramento St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['558 Sacramento St', 'San Francisco, CA 94111']},
#    'phone': '+14157729060',
#    'display_phone': '(415) 772-9060',
#    'distance': 4744.189084845839},
#   {'id': 'PFk6k_hEGG0n6_FAJSm9EQ',
#    'alias': 'woodhouse-fish-company-san-francisco-3',
#    'name': 'Woodhouse Fish Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/H0luh0if0BlL2qSdtuHkqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodhouse-fish-company-san-francisco-3?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 2240,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78742, 'longitude': -122.43327},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1914 Fillmore St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1914 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14154372722',
#    'display_phone': '(415) 437-2722',
#    'distance': 2966.614164301847},
#   {'id': 'ZDvIMjJ-7I0561ckM4pAeA',
#    'alias': 'anchor-oyster-bar-san-francisco',
#    'name': 'Anchor Oyster Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oKLPo1042ojJJC9OcCzAMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anchor-oyster-bar-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1513,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.759689, 'longitude': -122.434609},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '579 Castro St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['579 Castro St', 'San Francisco, CA 94114']},
#    'phone': '+14154313990',
#    'display_phone': '(415) 431-3990',
#    'distance': 210.29727091545175},
#   {'id': 'Gh3cLhqw1BqpFSN5BaemBg',
#    'alias': 'khamsa-san-francisco',
#    'name': 'Khamsa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bAfERDz9bPwVKgpEWTmSrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khamsa-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 218,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76654, 'longitude': -122.41798},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1503 15th St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1503 15th St', 'San Francisco, CA 94103']},
#    'phone': '+16282331503',
#    'display_phone': '(628) 233-1503',
#    'distance': 1745.6989802259407},
#   {'id': 'kFgjHGp-cTUK5uPaSJOORA',
#    'alias': 'souvla-san-francisco',
#    'name': 'Souvla',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/besB9ExGAUybD7-OmK3-gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/souvla-san-francisco?adjust_creative=0twhNDc137DaRrS6pAPpog&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0twhNDc137DaRrS6pAPpog',
#    'review_count': 1364,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77643, 'longitude': -122.425},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '517 Hayes St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['517 Hayes St', 'San Francisco, CA 94102']},
#    'phone': '+14154005458',
#    'display_phone': '(415) 400-5458',
#    'distance': 2003.2179011503324}],
#  'total': 4300,
#  'region': {'center': {'longitude': -122.43644714355469,
#    'latitude': 37.76089938976322}}}

# %%
# Set up containers to capture the data
#iterations = 0
restaurants = []
restaurant_count = 0

while restaurant_count < 1000:
#     iterations += 1
    try:
        print(f'Attempting to make API order... Restaurant Count: {restaurant_count}')
        payload = {
            'term': 'restaurants',
            'location': 'san francisco',
            'limit': 50,
            'offset': restaurant_count
        }

        # make the api call
        response = requests.get(uri, params=payload, headers=headers)
        print(f'Status Code: {response.status_code}')

        # grab the data
        data = response.json()
        print(f'Restaurant data: {data.keys()}')

        # add the results to our restaurants list [0].concat([1, 2, 3]) -> [0,1 2, 3, 4]
        restaurants += data['businesses']

        # keep track of the current count that we can offset the api call by
        restaurant_count += 50
    except:
        print(' Mr.Fullsack.. I dont feel so good...something went wrong in kitchen... Giving up')
# Out:
# Attempting to make API order... Restaurant Count: 0
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 50
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 100
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 150
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 200
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 250
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 300
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 350
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 400
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 450
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 500
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 550
# Status Code: 200
# Restaurant data: dict_keys(['businesses', 'total', 'region'])
# Attempting to make API order... Restaurant Count: 600

# %%
# check the number of dictionary objects in list
len(restaurants)

# %%
# checking to see if the data is not duplicate
restaurant_names = []

for obj in restaurants:
    restaurant_names.append(obj['name'])

# %%
restaurant_unique = set(restaurant_names)
print('Number of unique restaurants:', len(restaurant_unique))

# %%
# (NOTE: CONTAINS DUPLICATES)
pd.DataFrame(restaurants)

# %%
# Export ~1000 restaurant data to csv (NOTE: CONTAINS DUPLICATES)
pd.DataFrame(restaurants).to_csv('restaurants.csv', index=False)
